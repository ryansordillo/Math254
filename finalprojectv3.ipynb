# %% [markdown]
# <a href="https://colab.research.google.com/github/ryansordillo/Math254/blob/main/finalprojectv3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(dplyr)
library(ggplot2)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
head(police_killings)
View(police_killings)
# Out:
#   name               age gender raceethnicity   month    day year
# 1 A'donte Washington 16  Male   Black           February 23  2015
# 2 Aaron Rutledge     27  Male   White           April     2  2015
# 3 Aaron Siler        26  Male   White           March    14  2015
# 4 Aaron Valdez       25  Male   Hispanic/Latino March    11  2015
# 5 Adam Jovicic       29  Male   White           March    19  2015
# 6 Adam Reinhart      29  Male   White           March     7  2015
#   streetaddress          city         state ⋯ share_hispanic p_income h_income
# 1 Clearview Ln           Millbrook    AL    ⋯ 5.6            28375    51367
# 2 300 block Iris Park Dr Pineville    LA    ⋯ 0.5            14678    27972
# 3 22nd Ave and 56th St   Kenosha      WI    ⋯ 16.8           25286    45365
# 4 3000 Seminole Ave      South Gate   CA    ⋯ 98.8           17194    48295
# 5 364 Hiwood Ave         Munroe Falls OH    ⋯ 1.7            33954    68785
# 6 18th St and Palm Ln    Phoenix      AZ    ⋯ 79             15523    20833
#   county_income comp_income county_bucket nat_bucket pov  urate      college
# 1 54766         0.9379359   3             3          14.1 0.09768638 0.16850951
# 2 40930         0.6834107   2             1          28.8 0.06572379 0.11140236
# 3 54930         0.8258693   2             3          14.6 0.16629314 0.14731227
# 4 55909         0.8638144   3             3          11.7 0.12482727 0.05013293
# 5 49669         1.3848678   5             4          1.9  0.06354983 0.40395421
# 6 53596         0.3887044   1             1          58   0.07365145 0.10295519
#     name                    age     gender raceethnicity   month    day year
# 1   A'donte Washington      16      Male   Black           February 23  2015
# 2   Aaron Rutledge          27      Male   White           April     2  2015
# 3   Aaron Siler             26      Male   White           March    14  2015
# 4   Aaron Valdez            25      Male   Hispanic/Latino March    11  2015
# 5   Adam Jovicic            29      Male   White           March    19  2015
# 6   Adam Reinhart           29      Male   White           March     7  2015
# 7   Adrian Hernandez        22      Male   Hispanic/Latino March    27  2015
# 8   Adrian Solis            35      Male   Hispanic/Latino March    26  2015
# 9   Alan Alverson           44      Male   White           January  28  2015
# 10  Alan James              31      Male   White           February  7  2015
# 11  Albert Hanson Jr        76      Male   White           April    26  2015
# 12  Alec Ouzounian          40      Male   White           May      12  2015
# 13  Alejandro Salazar       Unknown Male   Hispanic/Latino February 20  2015
# 14  Alexander Long          31      Male   White           February 25  2015
# 15  Alexander Myers         23      Male   White           April     6  2015
# 16  Alexander Rivera        39      Male   Hispanic/Latino May      30  2015
# 17  Alexia Christian        25      Female Black           April    30  2015
# 18  Alfredo Rials-Torres    54      Male   Hispanic/Latino May      19  2015
# 19  Alice Brown             24      Female White           March    17  2015
# 20  Alvin Haynes            57      Male   Black           January  26  2015
# 21  Amilcar Perez-Lopez     21      Male   Hispanic/Latino February 26  2015
# 22  Andre Murphy Sr         42      Male   Black           January   7  2015
# 23  Andres Lara-Rodriguez   21      Male   Hispanic/Latino February 13  2015
# 24  Andrew Driver           36      Male   White           March    13  2015
# 25  Andrew Jackson          26      Male   White           April    29  2015
# 26  Andrew Shipley          49      Male   White           March    17  2015
# 27  Andrew Toto             54      Male   White           January  21  2015
# 28  Andrew Valadez          26      Male   White           April    23  2015
# 29  Andrew Williams         48      Male   Black           March     6  2015
# 30  Andy Martinez           33      Male   Hispanic/Latino January   9  2015
# ⋮   ⋮                       ⋮       ⋮      ⋮               ⋮        ⋮   ⋮
# 438 Tiffany Terry           39      Female White           January  30  2015
# 439 Tim Elliott             53      Male   Unknown         January   2  2015
# 440 Timothy Jones           27      Male   White           May      17  2015
# 441 Todd Allen Hodge        36      Male   White           January  21  2015
# 442 Todd Jamal Dye          20      Male   Black           April    24  2015
# 443 Tommy Smith             39      Male   White           January  12  2015
# 444 Tony Robinson           19      Male   Black           March     6  2015
# 445 Tony Ross               34      Male   White           March     6  2015
# 446 Troy Boyd               36      Male   White           March    15  2015
# 447 Tyrel Vick              34      Male   White           March    20  2015
# 448 Tyrell Larsen           31      Male   White           April     6  2015
# 449 Tyrone Ryerson          45      Male   Black           March     5  2015
# 450 Tyson Hubbard           34      Male   White           March     5  2015
# 451 Unknown                 Unknown Male   Unknown         January  16  2015
# 452 Unknown                 Unknown Female Unknown         May      25  2015
# 453 Unknown                 Unknown Male   White           June      1  2015
# 454 Victor Reyes            31      Male   Hispanic/Latino January  31  2015
# 455 Victor Terrazas         28      Male   Hispanic/Latino March    25  2015
# 456 Vincent Cordaro         57      Male   White           February  9  2015
# 457 Walter Brown III        29      Male   Black           March    24  2015
# 458 Walter Scott            50      Male   Black           April     4  2015
# 459 Wendell King            40      Male   White           January  29  2015
# 460 Wilber Castillo-Gongora 35      Male   Hispanic/Latino February  5  2015
# 461 William 'Rusty' Smith   53      Male   White           March    10  2015
# 462 William Campbell        59      Male   Unknown         January  25  2015
# 463 William Chapman II      18      Male   Black           April    22  2015
# 464 William Dick III        28      Male   Native American April     4  2015
# 465 William Poole           52      Male   White           March    16  2015
# 466 Yuvette Henderson       38      Female Black           February  3  2015
# 467 Zaki Shinwary           48      Male   Unknown         January  16  2015
#     streetaddress                             city                   state ⋯
# 1   Clearview Ln                              Millbrook              AL    ⋯
# 2   300 block Iris Park Dr                    Pineville              LA    ⋯
# 3   22nd Ave and 56th St                      Kenosha                WI    ⋯
# 4   3000 Seminole Ave                         South Gate             CA    ⋯
# 5   364 Hiwood Ave                            Munroe Falls           OH    ⋯
# 6   18th St and Palm Ln                       Phoenix                AZ    ⋯
# 7   4000 Union Ave                            Bakersfield            CA    ⋯
# 8   1500 Bayview Ave                          Wilmington             CA    ⋯
# 9   Pickett Runn Rd                           Sunset                 TX    ⋯
# 10  200 Abbie St SE                           Wyoming                MI    ⋯
# 11  7th Ave and Kansas Ave                    Hanford                CA    ⋯
# 12  28 Paseo Viento                           Rancho Santa Margarita CA    ⋯
# 13  1200 E Airtex Dr                          Houston                TX    ⋯
# 14  25th St and Poplar St                     Terre Haute            IN    ⋯
# 15  5700 block Ashby Dr                       Indianapolis           IN    ⋯
# 16  1128 Murfreesboro Pike                    Nashville              TN    ⋯
# 17  141 Pryor St SW                           Atlanta                GA    ⋯
# 18  4219 2nd Road N                           Arlington              VA    ⋯
# 19  Van Ness Ave and Pine St                  San Francisco          CA    ⋯
# 20  1 Moreland Dr                             San Francisco          CA    ⋯
# 21  Folsom St and 24th St                     San Francisco          CA    ⋯
# 22  1223 Omaha Ave                            Norfolk                NE    ⋯
# 23  S 12th St and Ruby St                     Kansas City            KS    ⋯
# 24  9700 Kempster Ave                         Fontana                CA    ⋯
# 25  1200 W Florida Ave                        Chickasha              OK    ⋯
# 26  360 Argyle Ct                             Medford                OR    ⋯
# 27  Scobie Pond Rd and Julian Rd              Derry                  NH    ⋯
# 28  Tyler St and Glenoaks Blvd                Sylmar                 CA    ⋯
# 29  Putnam Loop Rd                            Putnam Hall            FL    ⋯
# 30  4400 Tetons Dr                            El Paso                TX    ⋯
# ⋮   ⋮                                         ⋮                      ⋮     ⋱
# 438 1702 S 50th St                            Omaha                  NE    ⋯
# 439 600 E Island Lake Dr                      Shelton                WA    ⋯
# 440 111 Otero Dr                              Ruidoso                NM    ⋯
# 441 40200 Clark Dr                            Hemet                  CA    ⋯
# 442 1505 E Main St                            Trinidad               CO    ⋯
# 443 224 Circle Dr                             Arcola                 IL    ⋯
# 444 1125 Williamson St                        Madison                WI    ⋯
# 445 Lamar St and Whitworth St                 Sulphur Springs        TX    ⋯
# 446 McEwien Swamp Rd                          Ruth                   MS    ⋯
# 447 Oklahoma Hwy 48 and E1750 Rd              Wapanucka              OK    ⋯
# 448 E 100 N                                   Rigby                  ID    ⋯
# 449 468 E Plainfield Ave                      Milwaukee              WI    ⋯
# 450 27th St and Fletcher Ave                  Lincoln                NE    ⋯
# 451 Co Rd 2718                                Mabank                 TX    ⋯
# 452 6505 Shirley Ave                          Austin                 TX    ⋯
# 453 271 Greece Ridge Center Dr                Rochester              NY    ⋯
# 454 West Little York Rd                       Houston                TX    ⋯
# 455 10200 S Vermont Ave                       Los Angeles            CA    ⋯
# 456 N Little Tor Rd                           New City               NY    ⋯
# 457 19 Colin Drive S                          Portsmouth             VA    ⋯
# 458 1945 Remount Rd                           North Charleston       SC    ⋯
# 459 4800 Hildring Dr E                        Forth Worth            TX    ⋯
# 460 US-287                                    Electra                TX    ⋯
# 461 700 Valley St                             Hoover                 AL    ⋯
# 462 335 New Brooklyn Rd                       Berlin                 NJ    ⋯
# 463 1098 Frederick Blvd                       Portsmouth             VA    ⋯
# 464 Bureau of Indian Affairs Rd 66            Tonasket               WA    ⋯
# 465 130 Wedowee Ln                            Gaston                 NC    ⋯
# 466 3800 Hollis St                            Oakland                CA    ⋯
# 467 Lake Arrowhead Ave and Great Salt Lake Dr Fremont                CA    ⋯
#     share_hispanic p_income h_income county_income comp_income county_bucket
# 1   5.6            28375     51367    54766        0.9379359   3
# 2   0.5            14678     27972    40930        0.6834107   2
# 3   16.8           25286     45365    54930        0.8258693   2
# 4   98.8           17194     48295    55909        0.8638144   3
# 5   1.7            33954     68785    49669        1.3848678   5
# 6   79             15523     20833    53596        0.3887044   1
# 7   44.2           25949     58068    48552        1.1959960   4
# 8   84.1           25043     66543    55909        1.1902019   4
# 9   66.3           16778     30391    38310        0.7932916   2
# 10  26.5           22005     44553    51667        0.8623106   3
# 11  44.9           26916     56065    48133        1.1647934   4
# 12  12.9           51186    117413    75422        1.5567474   5
# 13  53.3           27414     53572    53137        1.0081864   3
# 14  3.1            25563     44857    40692        1.1023543   4
# 15  7.5            25998     39727    42334        0.9384183   3
# 16  24.7           20027     25500    47335        0.5387134   1
# 17  6.4            23205     56190    56857        0.9882688   3
# 18  15.7           29881     38125   103208        0.3693997   1
# 19  16.5           41676     61904    75604        0.8187927   2
# 20  15.2           37455    111903    88202        1.2687127   4
# 21  58.1           27384     60479    75604        0.7999444   2
# 22  2.9            23342     54809    46566        1.1770176   4
# 23  41.4           22719     32471    39402        0.8240952   2
# 24  76.4           18376     39153    54090        0.7238491   2
# 25  9.7            17695     32034    49637        0.6453654   1
# 26  15.1           21610     43625    44005        0.9913646   3
# 27  1.9            32921     61167    77348        0.7908026   1
# 28  77.9           22441     52344    55909        0.9362357   3
# 29  6.5            23926     36844    32497        1.1337662   4
# 30  89.9           13231     17388    40157        0.4330005   1
# ⋮   ⋮              ⋮        ⋮        ⋮             ⋮           ⋮
# 438 4              36394     66786   53325         1.2524332    4
# 439 18.1           18999     39495   48755         0.8100708    1
# 440 19.5           26934     48198   43014         1.1205189    5
# 441 38.4           17632     32708   56529         0.5786057    1
# 442 55.3           15498     25688   42261         0.6078417    1
# 443 20.9           27719     51518   52741         0.9768112    2
# 444 5.5            35028     53089   61721         0.8601448    2
# 445 8.5            19921     42282   43657         0.9685045    2
# 446 0.3            22213     46740   34841         1.3415229    5
# 447 1.1            25110     40000   34867         1.1472166   NA
# 448 8.4            27347     57256   52023         1.1005901   NA
# 449 15             35316     63444   43193         1.4688491    5
# 450 4.2            26597     40404   51574         0.7834180    2
# 451 10.4           22969     50280   43439         1.1574852    5
# 452 10.4           22969     50280   43439         1.1574852    5
# 453 10.4           22969     50280   43439         1.1574852    5
# 454 40.1           29695     41265   53137         0.7765775    2
# 455 60.3           16940     26250   55909         0.4695130    1
# 456 4.8            52896    142500   84951         1.6774376    5
# 457 0              27535     51480   46166         1.1151064    3
# 458 18.6           14963     19988   50792         0.3935265    1
# 459 6              54494    102938   56853         1.8105993    5
# 460 2.5            31761     62817   45086         1.3932706    5
# 461 7.7            42312     81996   45429         1.8049264    5
# 462 4.9            31470     65759   61683         1.0660798    3
# 463 0              25262     27418   46166         0.5939003    1
# 464 20.2           18470     35608   40368         0.8820848    1
# 465 0.3            21175     38200   42017         0.9091558    2
# 466 37.1           26971     63052   72112         0.8743621    2
# 467 12.3           33590     88940   72112         1.2333592    4
#     nat_bucket pov  urate      college
# 1   3          14.1 0.09768638 0.16850951
# 2   1          28.8 0.06572379 0.11140236
# 3   3          14.6 0.16629314 0.14731227
# 4   3          11.7 0.12482727 0.05013293
# 5   4          1.9  0.06354983 0.40395421
# 6   1          58   0.07365145 0.10295519
# 7   4          17.2 0.13146113 0.20380117
# 8   4          12.2 0.09434698 0.09043760
# 9   1          37.7 0.14083298 0.04760134
# 10  2          18.4 0.17416742 0.10269151
# 11  3          9.2  0.04108527 0.10032895
# 12  5          4.4  0.05758078 0.52717678
# 13  3          18.1 0.07377186 0.09580364
# 14  2          13.1 0.05447010 0.34585785
# 15  2          26   0.06732118 0.56803343
# 16  1          36.3 0.08822586 0.22681478
# 17  3          42.4 0.22948207 0.38053740
# 18  2          20.5 0.01191611 0.42496494
# 19  4          11.6 0.04085059 0.55254849
# 20  5          6.4  0.06326837 0.40952621
# 21  4          12.7 0.11589051 0.34988491
# 22  3          10.3 0.03522150 0.25888644
# 23  1          36.5 0.17818575 0.07093125
# 24  2          24.4 0.26297697 0.07150424
# 25  1          20.3 0.01133501 0.16940180
# 26  2          24.8 0.13115892 0.12573168
# 27  4          5.4  0.08738548 0.28485425
# 28  3          17.4 0.09898020 0.17937220
# 29  2          18.2 0.17614880 0.15356292
# 30  1          58.1 0.14461316 0.04723992
# ⋮   ⋮          ⋮    ⋮          ⋮
# 438 4          5.5  0.02841596 0.49617904
# 439 2          18.4 0.06419317 0.09115770
# 440 3          8.4  0.06605505 0.30657815
# 441 1          32   0.21684867 0.08590604
# 442 1          26.6 0.12590799 0.17092652
# 443 3          14   0.05373961 0.15882094
# 444 3          13.3 0.05525485 0.74490020
# 445 2          24.3 0.19769875 0.18205510
# 446 3          15.5 0.05514019 0.12794206
# 447 2          20.7 0.05624297 0.16370656
# 448 4          9.6  0.06899401 0.19408867
# 449 4          11   0.06534273 0.29601722
# 450 2          19.9 0.05573577 0.36238244
# 451 3          17.9 0.05857330 0.10024907
# 452 3          17.9 0.05857330 0.10024907
# 453 3          17.9 0.05857330 0.10024907
# 454 2          12.5 0.02356109 0.22967891
# 455 1          33.7 0.06643109 0.12200737
# 456 5          1.9  0.04500000 0.66991694
# 457 3          6.6  0.02893437 0.22578905
# 458 1          44.1 0.21590909 0.09294998
# 459 5          11.2 0.02757456 0.71127026
# 460 4          4    0.03451996 0.16980360
# 461 5          3    0.03591606 0.62763158
# 462 4          7.3  0.14086629 0.23610703
# 463 1          35.2 0.15204678 0.12055336
# 464 2          27.3 0.13365029 0.17452498
# 465 2          28.5 0.25614973 0.07276423
# 466 4          23.9 0.06960143 0.39647577
# 467 5          6.1  0.08091210 0.43577328

# %%
police_killings <- read.csv("police_killings.csv")

# %%
police_killings_clean <- police_killings %>%
  filter(if_all(everything(), ~ !grepl("unknown|^0$", ., ignore.case = TRUE)))%>%
  filter(!is.na(county_bucket))

police_killings_clean %>%
  ggplot()+
  aes(x= raceethnicity)+
  geom_bar()
# Out:
# Warning message:
# “There were 10 warnings in `filter()`.
# The first warning was:
# ℹ In argument: `&...`.
# Caused by warning in `grepl()`:
# ! unable to translate 'Rub<cc>_<e5><a9>n Garc<cc>__a Villalpando' to a wide string
# ℹ Run `dplyr::last_dplyr_warnings()` to see the 9 remaining warnings.”
# plot without title

# %%
police_killings_clean <- police_killings_clean %>%
  mutate(
    pop = as.numeric(pop),
    share_white = as.numeric(share_white),
    share_black = as.numeric(share_black),
    share_hispanic = as.numeric(share_hispanic)
  )

# %%
police_killings_clean <- police_killings_clean %>%
  mutate(
    whitepop = pop * share_white / 100,
    blackpop = pop * share_black / 100,
    hispanicpop = pop * share_hispanic / 100
  )

# %%
black_total_pop <- sum(police_killings_clean$blackpop)
white_total_pop <- sum(police_killings_clean$whitepop)
hispanic_total_pop <- sum(police_killings_clean$hispanicpop)

# %%
killings_and_population
# Out:
# Error: object 'killings_and_population' not found
# Traceback:

# %%
killings_by_race <- police_killings_clean %>%
  group_by(raceethnicity) %>%
  summarize(killings = n())


population_by_race <- data.frame(
  raceethnicity = c("White", "Black", "Hispanic/Latino"),
  population = c(white_total_pop, black_total_pop, hispanic_total_pop)
)


killings_and_population <- merge(killings_by_race, population_by_race, by = "raceethnicity")


killings_and_population <- killings_and_population %>%
  mutate(rate = (killings / population) * 100000)

ggplot(killings_and_population, aes(x = raceethnicity, y = rate)) +
  geom_col() +
  labs(title = "Police Killing Rate per 100,000 people by Race",
       x = "Race/Ethnicity",
       y = "Killings per 100,000 people")
# Out:
# plot without title

# %%
police_killings_clean %>%
  ggplot() +
  aes(x = raceethnicity, fill = as.factor(county_bucket)) +
  geom_bar()
# Out:
# plot without title

# %%
ggplot(police_killings_clean, aes(x = raceethnicity, fill = as.factor(county_bucket))) +
  geom_bar(position = "fill") +
  labs(title = "Killings by Race and County Income Quintile",
       x = "Race/Ethnicity",
       y = "Number of Killings",
       fill = "County Income Quintile")
# Out:
# plot without title

# %%
ggplot(police_killings_clean, aes(x = nat_bucket)) +
  geom_bar() +
  labs(title = "Killings by National Bucket Quintile and Race",
       x = "National Income Quintile",
       y = "Number of Killings")

ggplot(police_killings_clean, aes(x = nat_bucket, fill = raceethnicity)) +
  geom_bar() +
  labs(title = "Killings by National Bucket Quintile and Race",
       x = "National Income Quintile",
       y = "Number of Killings",
       fill = "Race/Ethnicity")

ggplot(police_killings_clean, aes(x = nat_bucket, fill = raceethnicity)) +
  geom_bar(position = "fill") +
  labs(title = "Proportion of Killings by National Bucket Quintile and Race",
       x = "National Income Quintile",
       y = "Proportion of Killings",
       fill = "Race/Ethnicity")

ggplot(police_killings_clean, aes(x = nat_bucket, fill = raceethnicity)) +
  geom_bar(position = "dodge") +
  labs(title = "Killings by National Bucket Quintile and Race",
       x = "National Income Quintile",
       y = "Number of Killings",
       fill = "Race/Ethnicity")
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %%
quintile1_2 <- police_killings_clean %>%
  filter(nat_bucket == 1 | nat_bucket == 2)

# %%
mean(quintile1_2$pop)
mean(police_killings_clean$pop)
# Out:
# [1] 4260.596
# [1] 4842.203

# %%
summary(police_killings_clean)
# Out:
#      name               age               gender          raceethnicity
#  Length:380         Length:380         Length:380         Length:380
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#     month                day             year      streetaddress
#  Length:380         Min.   : 1.00   Min.   :2015   Length:380
#  Class :character   1st Qu.: 8.00   1st Qu.:2015   Class :character
#  Mode  :character   Median :15.00   Median :2015   Mode  :character
#                     Mean   :15.53   Mean   :2015
#                     3rd Qu.:22.00   3rd Qu.:2015
#                     Max.   :31.00   Max.   :2015
#      city              state              latitude       longitude
#  Length:380         Length:380         Min.   :19.92   Min.   :-159.64
#  Class :character   Class :character   1st Qu.:33.28   1st Qu.:-112.01
#  Mode  :character   Mode  :character   Median :35.86   Median : -94.82
#                                        Mean   :36.46   Mean   : -97.16
#                                        3rd Qu.:40.04   3rd Qu.: -82.96
#                                        Max.   :61.22   Max.   : -68.10
#     state_fp       county_fp         tract_ce          geo_id
#  Min.   : 1.00   Min.   :  1.00   Min.   :   100   Min.   :1.003e+09
#  1st Qu.: 7.50   1st Qu.: 29.00   1st Qu.:  3850   1st Qu.:7.533e+09
#  Median :24.00   Median : 63.00   Median : 30370   Median :2.401e+10
#  Mean   :25.09   Mean   : 82.29   Mean   :189788   Mean   :2.518e+10
#  3rd Qu.:40.00   3rd Qu.:107.50   3rd Qu.:234776   3rd Qu.:4.011e+10
#  Max.   :56.00   Max.   :550.00   Max.   :978400   Max.   :5.601e+10
#    county_id       namelsad         lawenforcementagency    cause
#  Min.   : 1003   Length:380         Length:380           Length:380
#  1st Qu.: 7532   Class :character   Class :character     Class :character
#  Median :24010   Mode  :character   Mode  :character     Mode  :character
#  Mean   :25177
#  3rd Qu.:40110
#  Max.   :56005
#     armed                pop         share_white     share_black
#  Length:380         Min.   :  403   Min.   : 0.30   Min.   : 0.10
#  Class :character   1st Qu.: 3404   1st Qu.:27.35   1st Qu.: 2.10
#  Mode  :character   Median : 4500   Median :52.65   Median : 8.10
#                     Mean   : 4842   Mean   :50.74   Mean   :17.51
#                     3rd Qu.: 5866   3rd Qu.:75.40   3rd Qu.:22.73
#                     Max.   :26826   Max.   :97.20   Max.   :98.60
#  share_hispanic    p_income            h_income      county_income
#  Min.   : 0.10   Length:380         Min.   : 10290   Min.   : 25498
#  1st Qu.: 4.40   Class :character   1st Qu.: 32509   1st Qu.: 45215
#  Median :13.70   Mode  :character   Median : 42314   Median : 51342
#  Mean   :23.24                      Mean   : 47042   Mean   : 53564
#  3rd Qu.:35.92                      3rd Qu.: 57370   3rd Qu.: 57062
#  Max.   :98.80                      Max.   :142500   Max.   :110292
#   comp_income     county_bucket     nat_bucket        pov
#  Min.   :0.1840   Min.   :1.000   Min.   :1.000   Length:380
#  1st Qu.:0.6345   1st Qu.:1.000   1st Qu.:1.000   Class :character
#  Median :0.8436   Median :2.000   Median :2.000   Mode  :character
#  Mean   :0.8845   Mean   :2.471   Mean   :2.511
#  3rd Qu.:1.0761   3rd Qu.:4.000   3rd Qu.:4.000
#  Max.   :2.8652   Max.   :5.000   Max.   :5.000
#      urate            college           whitepop           blackpop
#  Min.   :0.01133   Min.   :0.01355   Min.   :   11.59   Min.   :   3.481
#  1st Qu.:0.06856   1st Qu.:0.11049   1st Qu.:  960.18   1st Qu.:  88.039
#  Median :0.10658   Median :0.17562   Median : 2062.62   Median : 349.297
#  Mean   :0.11650   Mean   :0.23178   Mean   : 2502.33   Mean   : 762.687
#  3rd Qu.:0.14066   3rd Qu.:0.31564   3rd Qu.: 3592.72   3rd Qu.:1086.678
#  Max.   :0.44807   Max.   :0.82807   Max.   :21219.37   Max.   :6631.320
#   hispanicpop
#  Min.   :    4.3
#  1st Qu.:  177.4
#  Median :  632.4
#  Mean   : 1166.5
#  3rd Qu.: 1569.8
#  Max.   :11189.6

# %%
summary(quintile1_2)
# Out:
#      name                age           gender          raceethnicity
#  Length:217         Min.   :16.00   Length:217         Length:217
#  Class :character   1st Qu.:27.00   Class :character   Class :character
#  Mode  :character   Median :35.00   Mode  :character   Mode  :character
#                     Mean   :36.23
#                     3rd Qu.:43.00
#                     Max.   :77.00
#     month                day             year      streetaddress
#  Length:217         Min.   : 1.00   Min.   :2015   Length:217
#  Class :character   1st Qu.: 8.00   1st Qu.:2015   Class :character
#  Mode  :character   Median :15.00   Median :2015   Mode  :character
#                     Mean   :15.46   Mean   :2015
#                     3rd Qu.:23.00   3rd Qu.:2015
#                     Max.   :31.00   Max.   :2015
#      city              state              latitude       longitude
#  Length:217         Length:217         Min.   :21.31   Min.   :-157.86
#  Class :character   Class :character   1st Qu.:33.50   1st Qu.:-111.98
#  Mode  :character   Mode  :character   Median :36.78   Median : -93.39
#                                        Mean   :37.00   Mean   : -96.80
#                                        3rd Qu.:40.63   3rd Qu.: -81.68
#                                        Max.   :61.22   Max.   : -70.93
#     state_fp       county_fp         tract_ce          geo_id
#  Min.   : 1.00   Min.   :  1.00   Min.   :   100   Min.   :1.073e+09
#  1st Qu.:10.00   1st Qu.: 21.00   1st Qu.:  3100   1st Qu.:1.000e+10
#  Median :26.00   Median : 55.00   Median : 31200   Median :2.602e+10
#  Mean   :26.38   Mean   : 76.11   Mean   :177992   Mean   :2.646e+10
#  3rd Qu.:40.00   3rd Qu.:103.00   3rd Qu.:210101   3rd Qu.:4.014e+10
#  Max.   :55.00   Max.   :550.00   Max.   :970500   Max.   :5.506e+10
#    county_id       namelsad         lawenforcementagency    cause
#  Min.   : 1073   Length:217         Length:217           Length:217
#  1st Qu.:10003   Class :character   Class :character     Class :character
#  Median :26017   Mode  :character   Mode  :character     Mode  :character
#  Mean   :26459
#  3rd Qu.:40143
#  Max.   :55059
#     armed                pop         share_white     share_black
#  Length:217         Min.   :  403   Min.   : 0.30   Min.   : 0.10
#  Class :character   1st Qu.: 3035   1st Qu.:17.80   1st Qu.: 4.40
#  Mode  :character   Median : 4149   Median :41.50   Median :11.70
#                     Mean   : 4281   Mean   :42.53   Mean   :22.73
#                     3rd Qu.: 5199   3rd Qu.:62.70   3rd Qu.:31.80
#                     Max.   :11284   Max.   :96.30   Max.   :98.60
#  share_hispanic    p_income            h_income     county_income
#  Min.   : 0.10   Length:217         Min.   :10290   Min.   : 25498
#  1st Qu.: 5.00   Class :character   1st Qu.:26964   1st Qu.: 45429
#  Median :18.60   Mode  :character   Median :34219   Median : 53137
#  Mean   :26.49                      Mean   :35754   Mean   : 54715
#  3rd Qu.:41.40                      3rd Qu.:41875   3rd Qu.: 59394
#  Max.   :96.30                      Max.   :80962   Max.   :103208
#   comp_income     county_bucket     nat_bucket        pov
#  Min.   :0.1840   Min.   :1.000   Min.   :1.000   Length:217
#  1st Qu.:0.5437   1st Qu.:1.000   1st Qu.:1.000   Class :character
#  Median :0.6598   Median :1.000   Median :1.000   Mode  :character
#  Mean   :0.6574   Mean   :1.401   Mean   :1.779
#  3rd Qu.:0.7920   3rd Qu.:2.000   3rd Qu.:2.000
#  Max.   :1.0287   Max.   :2.000   Max.   :5.000
#      urate            college           whitepop          blackpop
#  Min.   :0.01133   Min.   :0.01355   Min.   :  11.59   Min.   :   3.481
#  1st Qu.:0.09157   1st Qu.:0.09217   1st Qu.: 634.89   1st Qu.: 153.062
#  Median :0.12591   Median :0.14203   Median :1502.36   Median : 473.928
#  Mean   :0.13869   Mean   :0.17979   Mean   :1782.84   Mean   : 901.921
#  3rd Qu.:0.17133   3rd Qu.:0.22823   3rd Qu.:2798.53   3rd Qu.:1287.582
#  Max.   :0.44807   Max.   :0.74490   Max.   :6227.57   Max.   :5754.840
#   hispanicpop       n_killings
#  Min.   :   4.3   Min.   : 1.00
#  1st Qu.: 173.2   1st Qu.:32.00
#  Median : 764.5   Median :39.00
#  Mean   :1251.5   Mean   :37.85
#  3rd Qu.:1804.8   3rd Qu.:47.00
#  Max.   :9340.1   Max.   :52.00

# %%
police_killings_clean %>%
  count(state)
# Out:
#    state n
# 1  AK     2
# 2  AL     7
# 3  AR     3
# 4  AZ    20
# 5  CA    63
# 6  CO    10
# 7  CT     1
# 8  DC     1
# 9  DE     2
# 10 FL    23
# 11 GA    12
# 12 HI     4
# 13 IA     2
# 14 ID     2
# 15 IL    10
# 16 IN     7
# 17 KS     6
# 18 KY     4
# 19 LA     8
# 20 MA     4
# 21 MD     7
# 22 ME     1
# 23 MI     8
# 24 MN     6
# 25 MO     8
# 26 MS     4
# 27 MT     2
# 28 NC     9
# 29 NE     4
# 30 NH     1
# 31 NJ     9
# 32 NM     3
# 33 NV     2
# 34 NY    11
# 35 OH     6
# 36 OK    20
# 37 OR     5
# 38 PA     7
# 39 SC     8
# 40 TN     5
# 41 TX    37
# 42 UT     4
# 43 VA     6
# 44 WA     9
# 45 WI     5
# 46 WV     1
# 47 WY     1

# %% [markdown]
# comparing summary stats, unemployment is up and college education is down in lower income areas

# %%
ggplot(quintile1_2, aes(x = longitude, y = latitude)) +
  geom_bin2d() +
  labs(title = "Heatmap of Police Killings by Location for Quintile1 and Quintile2",
       x = "Longitude",
       y = "Latitude") +
  scale_fill_gradient(low = "white", high = "red")
# Out:
# plot without title

# %%
ggplot(police_killings_clean, aes(x = longitude, y = latitude)) +
  geom_bin2d() +
  labs(title = "Heatmap of Police Killings by Location",
       x = "Longitude",
       y = "Latitude") +
  scale_fill_gradient(low = "white", high = "red")
# Out:
# plot without title

# %%
head(police_killings_clean)
# Out:
#   name               age gender raceethnicity   month    day year
# 1 A'donte Washington 16  Male   Black           February 23  2015
# 2 Aaron Rutledge     27  Male   White           April     2  2015
# 3 Aaron Siler        26  Male   White           March    14  2015
# 4 Aaron Valdez       25  Male   Hispanic/Latino March    11  2015
# 5 Adam Jovicic       29  Male   White           March    19  2015
# 6 Adam Reinhart      29  Male   White           March     7  2015
#   streetaddress          city         state ⋯ comp_income county_bucket
# 1 Clearview Ln           Millbrook    AL    ⋯ 0.9379359   3
# 2 300 block Iris Park Dr Pineville    LA    ⋯ 0.6834107   2
# 3 22nd Ave and 56th St   Kenosha      WI    ⋯ 0.8258693   2
# 4 3000 Seminole Ave      South Gate   CA    ⋯ 0.8638144   3
# 5 364 Hiwood Ave         Munroe Falls OH    ⋯ 1.3848678   5
# 6 18th St and Palm Ln    Phoenix      AZ    ⋯ 0.3887044   1
#   nat_bucket pov  urate      college    whitepop blackpop hispanicpop
# 1 3          14.1 0.09768638 0.16850951 2286.295 1152.595  211.624
# 2 1          28.8 0.06572379 0.11140236 1489.722 1002.378   13.845
# 3 3          14.6 0.16629314 0.14731227 3010.302  314.083  685.272
# 4 3          11.7 0.12482727 0.05013293   52.116   26.058 4290.884
# 5 4          1.9  0.06354983 0.40395421 6298.325   95.326  115.753
# 6 1          58   0.07365145 0.10295519  327.740  360.514 3698.780
#   n_killings
# 1 15
# 2 39
# 3 39
# 4 13
# 5 35
# 6 52

# %%
subset_killings <- police_killings_clean %>%
  filter(state %in% c("CA", "TX", "FL"))

# %% [markdown]
# by age?
# distribution of killings per race by age

# %%
police_killings_clean <- police_killings_clean %>%
  mutate(age = as.numeric(age))

# %%
police_killings_clean %>%
  ggplot()+
  aes(x = age)+
  geom_density()+
  facet_wrap(~ raceethnicity)
# Out:
# plot without title

# %%
quintile1_2 %>%
  ggplot()+
  aes(x = age)+
  geom_density()+
  facet_wrap(~ raceethnicity)
# Out:
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# plot without title

# %%
# prompt: cause of death on x axis stack by race per 100 incidents of each

# Assuming 'cause' is the column representing cause of death
ggplot(police_killings_clean, aes(x = cause, fill = raceethnicity)) +
  geom_bar(position = "dodge") +  # Use position = "fill" for proportions
  labs(title = "Proportion of Killings by Cause of Death and Race",
       x = "Cause of Death",
       y = "Proportion of Killings",
       fill = "Race/Ethnicity") +
  theme(axis.text.x = element_text(angle = 45, hjust = 1)) # Rotate x-axis labels if needed
# Out:
# plot without title

# %%
ggplot(quintile1_2, aes(x = cause, fill = raceethnicity)) +
  geom_bar(position = "dodge") +  # Use position = "fill" for proportions
  labs(title = "Proportion of Killings by Cause of Death and Race",
       x = "Cause of Death",
       y = "Proportion of Killings",
       fill = "Race/Ethnicity") +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %%
incident_count <- police_killings_clean %>% group_by(state) %>% summarise(frequency_of_incidents = n())

police_killings_clean <- police_killings_clean %>% left_join(incident_count, by = "state")

# %%
# Aggregate data to get one data point per state
state_data <- police_killings_clean %>%
  group_by(state, cause) %>%
  summarise(
    mean_h_income = mean(h_income, na.rm = TRUE),
    frequency_of_incidents = n(),
    most_common_race = names(sort(table(raceethnicity), decreasing = TRUE)[1]),
    mean_pov = mean(pov, na.rm = TRUE),
    mean_urate = mean(urate, na.rm = TRUE),
    .groups = 'drop'
  )
# Out:
# Warning message:
# “There were 79 warnings in `summarise()`.
# The first warning was:
# ℹ In argument: `mean_pov = mean(pov, na.rm = TRUE)`.
# ℹ In group 1: `state = "AK"` and `cause = "Death in custody"`.
# Caused by warning in `mean.default()`:
# ! argument is not numeric or logical: returning NA
# ℹ Run `dplyr::last_dplyr_warnings()` to see the 78 remaining warnings.”

# %%
ggplot(state_data) +
  aes(x = frequency_of_incidents, y = YESNOARMED, col = cause) +
  geom_jitter(height = 0.01, width = 0) +
  labs(
    x = "Median Household Income",
    y = "Frequency of Incidents",
    title = "Scatterplot of Frequency of Incidents by Median Household Income and Cause of Death",
    color = "Cause of Death"
  ) +
  theme_minimal()
# Out:
# plot without title

# %%
# prompt: what question should i ask next

# Consider these questions:

# 1.  Data Exploration and Cleaning:
#  * How many missing values are there in each column?
#  * What are the unique values for the 'raceethnicity' and 'manner_of_death' columns?
#  * Are there any outliers or inconsistencies in the data that need addressing?
#  * What is the distribution of ages in the dataset?

# 2. Visualization Enhancements:
# * Can we improve the readability of the bar chart (e.g. add labels, change colors)?
#  * How does the distribution of raceethnicity vary across different states or cities?
#  * Create a visualization showing the relationship between age and manner of death.
#  * Is there a correlation between the victim's mental illness status and the outcome?

# 3.  Statistical Analysis:
# * What is the proportion of killings for each raceethnicity group?
# * Are there significant differences in killing rates among different racial groups?
# * Is there a correlation between the manner of death and the victim's raceethnicity?

# 4. Addressing Ethical Considerations:
# * How might biases in data collection impact the results?
# * What are some limitations of the data, and how might they affect our conclusions?
# * What are some potential next steps in analyzing the data, and what additional data sources could be helpful?

# Example of a more specific question based on the provided code:
# "How can I order the bars in the bar chart of raceethnicity by frequency to improve readability?"
